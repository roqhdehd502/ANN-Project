# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_values = [1, 2, 3]
y_values = [0.3250, 0.3230, 0.3375]
plt.plot(x_values, y_values)
plt.grid()
plt.xlabel('Learning Cycle')
plt.ylabel('Accuracy')
plt.title('Accuracy Trend Graph')
plt.show()
